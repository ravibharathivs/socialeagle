# %% [markdown]
# # Propmt for CorrectiveRAG
#
# ### Role:
#
# *   Step1 (Context Evaluation):
#     1.   Rate the following retrieve context for the given query:
#         -   Query: {user query input}
#         -   Retrieved context : {retrieved_context}
#     it evaluates the above two contexts.
#
#     2.  Evaluate Criteria:
