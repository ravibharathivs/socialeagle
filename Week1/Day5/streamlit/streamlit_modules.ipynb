# %% [markdown]
# ## StreamLit framework
#
# ### Streamlit modules
# 1. Text Elements
# 2. Input Widgets
# 3. CHarts & graphs
# 4. Media & Files
# 5. Data Display
# 6. Layout & Control

# %% [markdown]
# ## Stream Components
#
#
# 1. Text & Rich content
#     * streamlit as st
#     * st.title(),st.header(), st.subheader()
#     * st.text(), st.markdown(), st.caption()
#     * st.latex(), st.code(), st.write()
#     * more
#
# 2. Input Widgets
#     * st.inputs(), st.checkbox(),st.radio()
#     * st.selectbox(), st.multiselect(),st.slider(),st.select_slider()
#     * more
#
# 3. Media & Files
#     * st.image, st.audion(),st.video()
#
# 4. Data Display
#     * st.dataframe(),st.table(), st.json()
#     * st.metric() (key value display)
#
# 5. Charts and Graphs
#     * st.line_chart(),st.area_chart(),st.bar_chart()
#     * more
#
# 6. Layout & Containers
#     * st.sidebar( all widgets can live here)
#     * st.columns(), st.expander(), st.container(),st.empty()
#     * more
